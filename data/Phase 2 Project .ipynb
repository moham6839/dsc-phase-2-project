# %% [markdown]
# # Data Cleaning/EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations
import scipy.stats as stats
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650     1.0         NaN   0.0  ...      7        1180
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 2         10000     1.0         0.0   0.0  ...      6         770
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# std    4.141264e+04      0.539683      0.086825      0.765686      0.650546
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068500e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above      yr_built  yr_renovated       zipcode  \
# count  21597.000000  21597.000000  21597.000000  17755.000000  21597.000000
# mean       7.657915   1788.596842   1970.999676     83.636778  98077.951845
# std        1.173200    827.759761     29.375234    399.946414     53.513072
# min        3.000000    370.000000   1900.000000      0.000000  98001.000000
# 25%        7.000000   1190.000000   1951.000000      0.000000  98033.000000
# 50%        7.000000   1560.000000   1975.000000      0.000000  98065.000000
# 75%        8.000000   2210.000000   1997.000000      0.000000  98118.000000
# max       13.000000   9410.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000   21597.000000   21597.000000
# mean      47.560093   -122.213982    1986.620318   12758.283512
# std        0.138552      0.140724     685.230472   27274.441950
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.471100   -122.328000    1490.000000    5100.000000
# 50%       47.571800   -122.231000    1840.000000    7620.000000
# 75%       47.678000   -122.125000    2360.000000   10083.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# In two of the categories that had missing data, I used the median to fill in the NaN values. For the yr_renovated column, since the median was 0, I used the most frequent year in the data:

# %%
df.view = df.view.fillna(value=df.view.median())

# %%
df.waterfront = df.waterfront.fillna(value=df.waterfront.median())

# %%
df.yr_renovated = df.yr_renovated.fillna(2014)

# %%
df = df[df.sqft_basement != '?']

# %%
df['sqft_basement'] = df['sqft_basement'].astype('float')
# Out:
# <ipython-input-10-71d394e26864>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sqft_basement'] = df['sqft_basement'].astype('float')

# %%
df['sqft_basement'].unique()
# Out:
# array([   0.,  400.,  910., 1530.,  730., 1700.,  300.,  970.,  760.,
#         720.,  700.,  820.,  780.,  790.,  330., 1620.,  360.,  588.,
#        1510.,  410.,  990.,  600.,  560.,  550., 1000., 1600.,  500.,
#        1040.,  880., 1010.,  240.,  265.,  290.,  800.,  540.,  710.,
#         840.,  380.,  770.,  480.,  570., 1490.,  620., 1250., 1270.,
#         120.,  650.,  180., 1130.,  450., 1640., 1460., 1020., 1030.,
#         750.,  640., 1070.,  490., 1310.,  630., 2000.,  390.,  430.,
#         850.,  210., 1430., 1950.,  440.,  220., 1160.,  860.,  580.,
#        2060., 1820., 1180.,  200., 1150., 1200.,  680.,  530., 1450.,
#        1170., 1080.,  960.,  280.,  870., 1100.,  460., 1400.,  660.,
#        1220.,  900.,  420., 1580., 1380.,  475.,  690.,  270.,  350.,
#         935., 1370.,  980., 1470.,  160.,  950.,   50.,  740., 1780.,
#        1900.,  340.,  470.,  370.,  140., 1760.,  130.,  520.,  890.,
#        1110.,  150., 1720.,  810.,  190., 1290.,  670., 1800., 1120.,
#        1810.,   60., 1050.,  940.,  310.,  930., 1390.,  610., 1830.,
#        1300.,  510., 1330., 1590.,  920., 1320., 1420., 1240., 1960.,
#        1560., 2020., 1190., 2110., 1280.,  250., 2390., 1230.,  170.,
#         830., 1260., 1410., 1340.,  590., 1500., 1140.,  260.,  100.,
#         320., 1480., 1060., 1284., 1670., 1350., 2570., 1090.,  110.,
#        2500.,   90., 1940., 1550., 2350., 2490., 1481., 1360., 1135.,
#        1520., 1850., 1660., 2130., 2600., 1690.,  243., 1210., 1024.,
#        1798., 1610., 1440., 1570., 1650.,  704., 1910., 1630., 2360.,
#        1852., 2090., 2400., 1790., 2150.,  230.,   70., 1680., 2100.,
#        3000., 1870., 1710., 2030.,  875., 1540., 2850., 2170.,  506.,
#         906.,  145., 2040.,  784., 1750.,  374.,  518., 2720., 2730.,
#        1840., 3480., 2160., 1920., 2330., 1860., 2050., 4820., 1913.,
#          80., 2010., 3260., 2200.,  415., 1730.,  652., 2196., 1930.,
#         515.,   40., 2080., 2580., 1548., 1740.,  235.,  861., 1890.,
#        2220.,  792., 2070., 4130., 2250., 2240., 1990.,  768., 2550.,
#         435., 1008., 2300., 2610.,  666., 3500.,  172., 1816., 2190.,
#        1245., 1525., 1880.,  862.,  946., 1281.,  414., 2180.,  276.,
#        1248.,  602.,  516.,  176.,  225., 1275.,  266.,  283.,   65.,
#        2310.,   10., 1770., 2120.,  295.,  207.,  915.,  556.,  417.,
#         143.,  508., 2810.,   20.,  274.,  248.])

# %%
df['price'] = df['price'].astype('int64')
# Out:
# <ipython-input-12-2557eed608a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = df['price'].astype('int64')

# %%
 df.hist(figsize=(18,15), bins='auto');

# %% [markdown]
# ## Ordinary Least Squares Model

# %%
df = df.drop(['id', 'date'],axis=1)

# %%
X = df.drop('price', axis=1)
Y = df[['price']]
Y.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0         0.0   0.0
# 1         3       2.25         2570      7242     2.0         0.0   0.0
# 2         2       1.00          770     10000     1.0         0.0   0.0
# 3         4       3.00         1960      5000     1.0         0.0   0.0
# 4         3       2.00         1680      8080     1.0         0.0   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180            0.0      1955           0.0
# 1          3      7        2170          400.0      1951        1991.0
# 2          3      6         770            0.0      1933        2014.0
# 3          5      7        1050          910.0      1965           0.0
# 4          3      8        1680            0.0      1987           0.0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062
# 3    98136  47.5208 -122.393           1360        5000
# 4    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# ## Model 1:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(len(X_train), len(X_test), len(Y_train), len(Y_test))
# Out:
# 16914 4229 16914 4229

# %%
linreg = LinearRegression()
linreg.fit(X_train, Y_train)

Y_hat_train = linreg.predict(X_train)
Y_hat_test = linreg.predict(X_test)

# %%
train_residuals = Y_hat_train - Y_train
test_residuals = Y_hat_test - Y_test

# %%
train_mse = mean_squared_error(Y_train, Y_hat_train)
test_mse = mean_squared_error(Y_test, Y_hat_test)
print('Train Mean Squared Error:', train_mse)
print('Test Mean Squared Error:', test_mse)
print("Train RMSE: ", train_mse**0.5)
print("Test RMSE: ", test_mse**0.5)
# Out:
# Train Mean Squared Error: 41037057146.92651
# Test Mean Squared Error: 39253929860.067154
# Train RMSE:  202576.05274791617
# Test RMSE:  198126.04538542416

# %%
'price' + '~' + '+'.join(X.columns)
# Out:
# 'price~bedrooms+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+condition+grade+sqft_above+sqft_basement+yr_built+yr_renovated+zipcode+lat+long+sqft_living15+sqft_lot15'

# %%
f = 'price' + '~' + '+'.join(X.columns)

# %%
model = ols(formula=f, data=df).fit()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2899.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:12   Log-Likelihood:            -2.8824e+05
# No. Observations:               21143   AIC:                         5.765e+05
# Df Residuals:                   21125   BIC:                         5.767e+05
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept       7.81e+06   2.96e+06      2.636      0.008       2e+06    1.36e+07
# bedrooms       -3.62e+04   1926.330    -18.793      0.000      -4e+04   -3.24e+04
# bathrooms      4.325e+04   3285.708     13.164      0.000    3.68e+04    4.97e+04
# sqft_living     110.6012      2.305     47.988      0.000     106.084     115.119
# sqft_lot          0.1138      0.049      2.324      0.020       0.018       0.210
# floors         7996.3253   3649.049      2.191      0.028     843.911    1.51e+04
# waterfront     6.292e+05   1.84e+04     34.196      0.000    5.93e+05    6.65e+05
# view           5.412e+04   2149.480     25.180      0.000    4.99e+04    5.83e+04
# condition      2.523e+04   2353.227     10.720      0.000    2.06e+04    2.98e+04
# grade          9.701e+04   2185.455     44.387      0.000    9.27e+04    1.01e+05
# sqft_above       70.3563      2.280     30.859      0.000      65.887      74.825
# sqft_basement    40.2503      2.683     15.004      0.000      34.992      45.509
# yr_built      -2742.1547     70.465    -38.915      0.000   -2880.271   -2604.039
# yr_renovated      4.1103      1.706      2.409      0.016       0.766       7.455
# zipcode        -590.4422     33.404    -17.676      0.000    -655.917    -524.968
# lat            5.981e+05   1.09e+04     55.045      0.000    5.77e+05    6.19e+05
# long          -2.157e+05   1.33e+04    -16.188      0.000   -2.42e+05    -1.9e+05
# sqft_living15    21.3448      3.486      6.122      0.000      14.511      28.179
# sqft_lot15       -0.3756      0.075     -5.019      0.000      -0.522      -0.229
# ==============================================================================
# Omnibus:                    17967.838   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1812690.746
# Skew:                           3.563   Prob(JB):                         0.00
# Kurtosis:                      47.798   Cond. No.                     2.79e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.76e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
resid1 = model.resid
fig = sm.graphics.qqplot(resid1, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model.resid, bins=100)
# Out:
# (array([2.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 4.000e+00, 2.000e+00,
#         3.000e+00, 4.000e+00, 1.000e+01, 1.600e+01, 1.500e+01, 2.300e+01,
#         4.700e+01, 8.900e+01, 1.480e+02, 3.580e+02, 6.200e+02, 1.108e+03,
#         1.781e+03, 2.578e+03, 3.424e+03, 3.476e+03, 2.935e+03, 1.937e+03,
#         1.046e+03, 4.730e+02, 2.740e+02, 1.790e+02, 8.900e+01, 9.400e+01,
#         6.100e+01, 4.100e+01, 4.500e+01, 4.300e+01, 3.400e+01, 2.800e+01,
#         1.700e+01, 1.700e+01, 1.900e+01, 8.000e+00, 1.000e+01, 1.000e+01,
#         1.300e+01, 9.000e+00, 5.000e+00, 5.000e+00, 6.000e+00, 5.000e+00,
#         4.000e+00, 2.000e+00, 5.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-1171698.53838759, -1116619.10845691, -1061539.67852622,
#         -1006460.24859553,  -951380.81866484,  -896301.38873415,
#          -841221.95880347,  -786142.52887278,  -731063.09894209,
#          -675983.6690114 ,  -620904.23908072,  -565824.80915003,
#          -510745.37921934,  -455665.94928865,  -400586.51935797,
#          -345507.08942728,  -290427.65949659,  -235348.2295659 ,
#          -180268.79963522,  -125189.36970453,   -70109.93977384,
#           -15030.50984315,    40048.92008754,    95128.35001822,
#           150207.77994891,   205287.2098796 ,   260366.63981029,
#           315446.06974097,   370525.49967166,   425604.92960235,
#           480684.35953304,   535763.78946372,   590843.21939441,
#           645922.6493251 ,   701002.07925579,   756081.50918648,
#           811160.93911716,   866240.36904785,   921319.79897854,
#           976399.22890923,  1031478.65883991,  1086558.0887706 ,
#          1141637.51870129,  1196716.94863198,  1251796.37856266,
#          1306875.80849335,  1361955.23842404,  1417034.66835473,
#          1472114.09828541,  1527193.5282161 ,  1582272.95814679,
#          1637352.38807748,  1692431.81800817,  1747511.24793885,
#          1802590.67786954,  1857670.10780023,  1912749.53773092,
#          1967828.9676616 ,  2022908.39759229,  2077987.82752298,
#          2133067.25745367,  2188146.68738435,  2243226.11731504,
#          2298305.54724573,  2353384.97717642,  2408464.40710711,
#          2463543.83703779,  2518623.26696848,  2573702.69689917,
#          2628782.12682986,  2683861.55676054,  2738940.98669123,
#          2794020.41662192,  2849099.84655261,  2904179.27648329,
#          2959258.70641398,  3014338.13634467,  3069417.56627536,
#          3124496.99620604,  3179576.42613673,  3234655.85606742,
#          3289735.28599811,  3344814.71592879,  3399894.14585948,
#          3454973.57579017,  3510053.00572086,  3565132.43565155,
#          3620211.86558223,  3675291.29551292,  3730370.72544361,
#          3785450.1553743 ,  3840529.58530498,  3895609.01523567,
#          3950688.44516636,  4005767.87509705,  4060847.30502773,
#          4115926.73495842,  4171006.16488911,  4226085.5948198 ,
#          4281165.02475049,  4336244.45468117]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# On the x-axis we have the actual price, and on the y-axis we have the residual:
# after 2-3 million dollars, we have low predictive power, consistently underpredicting house prices.

# %%
plt.scatter(Y, model.resid)
plt.title('Initial Model: Actual Price vs. Residual ')
plt.xlabel('Actual Price(Per Million $)')
plt.ylabel('Residual')
plt.show()

# %%
for column in df:
    df[column].plot.hist(density=True, label = column+' histogram')
    df[column].plot.kde(label =column+' kde')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Model 2: Removing Outliers
# In this part, I focused on identifying and removing outliers using Z-Score. From that, I used the new DataFrame without outliers to conduct another statsmodel:

# %%
df_no_outliers = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
df_no_outliers
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0      221900         3       1.00         1180      5650     1.0         0.0
# 1      538000         3       2.25         2570      7242     2.0         0.0
# 2      180000         2       1.00          770     10000     1.0         0.0
# 3      604000         4       3.00         1960      5000     1.0         0.0
# 4      510000         3       2.00         1680      8080     1.0         0.0
# ...       ...       ...        ...          ...       ...     ...         ...
# 21592  360000         3       2.50         1530      1131     3.0         0.0
# 21593  400000         4       2.50         2310      5813     2.0         0.0
# 21594  402101         2       0.75         1020      1350     2.0         0.0
# 21595  400000         3       2.50         1600      2388     2.0         0.0
# 21596  325000         2       0.75         1020      1076     2.0         0.0
#
#        view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0       0.0          3      7        1180            0.0      1955
# 1       0.0          3      7        2170          400.0      1951
# 2       0.0          3      6         770            0.0      1933
# 3       0.0          5      7        1050          910.0      1965
# 4       0.0          3      8        1680            0.0      1987
# ...     ...        ...    ...         ...            ...       ...
# 21592   0.0          3      8        1530            0.0      2009
# 21593   0.0          3      8        2310            0.0      2014
# 21594   0.0          3      7        1020            0.0      2009
# 21595   0.0          3      8        1600            0.0      2004
# 21596   0.0          3      7        1020            0.0      2008
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0               0.0    98178  47.5112 -122.257           1340        5650
# 1            1991.0    98125  47.7210 -122.319           1690        7639
# 2            2014.0    98028  47.7379 -122.233           2720        8062
# 3               0.0    98136  47.5208 -122.393           1360        5000
# 4               0.0    98074  47.6168 -122.045           1800        7503
# ...             ...      ...      ...      ...            ...         ...
# 21592           0.0    98103  47.6993 -122.346           1530        1509
# 21593           0.0    98146  47.5107 -122.362           1830        7200
# 21594           0.0    98144  47.5944 -122.299           1020        2007
# 21595           0.0    98027  47.5345 -122.069           1410        1287
# 21596           0.0    98144  47.5941 -122.299           1020        1357
#
# [19023 rows x 19 columns]

# %%
x = df_no_outliers.drop('price', axis=1)
y = df_no_outliers[['price']]
y.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
df_no_outliers.shape
# Out:
# (19023, 19)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(len(x_train), len(x_test), len(y_train), len(y_test))
# Out:
# 15218 3805 15218 3805

# %%
linreg = LinearRegression()
linreg.fit(x_train, y_train)

y_hat_train = linreg.predict(x_train)
y_hat_test = linreg.predict(x_test)

# %%
second_train_residuals = y_hat_train - y_train
second_test_residuals = y_hat_test - y_test

# %%
second_train_mse = mean_squared_error(y_train, y_hat_train)
second_test_mse = mean_squared_error(y_test, y_hat_test)
print('Train Mean Squared Error:', second_train_mse)
print('Test Mean Squared Error:', second_test_mse)
print("Train RMSE: ", second_train_mse**0.5)
print("Test RMSE: ", second_test_mse**0.5)
# Out:
# Train Mean Squared Error: 17569949589.706013
# Test Mean Squared Error: 18426609397.332294
# Train RMSE:  132551.68648382416
# Test RMSE:  135744.64776679888

# %%
'price' + '~' + '+'.join(x.columns)
# Out:
# 'price~bedrooms+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+condition+grade+sqft_above+sqft_basement+yr_built+yr_renovated+zipcode+lat+long+sqft_living15+sqft_lot15'

# %%
f2 = 'price' + '~' + '+'.join(x.columns)

# %%
model2 = ols(formula=f2, data=df_no_outliers).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     2517.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:18   Log-Likelihood:            -2.5145e+05
# No. Observations:               19023   AIC:                         5.029e+05
# Df Residuals:                   19006   BIC:                         5.031e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -3.702e+05   2.09e+06     -0.177      0.859   -4.46e+06    3.72e+06
# bedrooms      -1.501e+04   1486.368    -10.097      0.000   -1.79e+04   -1.21e+04
# bathrooms      3.043e+04   2429.125     12.528      0.000    2.57e+04    3.52e+04
# sqft_living      64.2421      1.859     34.557      0.000      60.598      67.886
# sqft_lot          0.2504      0.146      1.717      0.086      -0.035       0.536
# floors         2.944e+04   2643.265     11.136      0.000    2.43e+04    3.46e+04
# waterfront    -2.266e-06   1.28e-05     -0.177      0.859   -2.73e-05    2.28e-05
# view           4.029e+04   2471.776     16.299      0.000    3.54e+04    4.51e+04
# condition      2.682e+04   1664.715     16.109      0.000    2.36e+04    3.01e+04
# grade          8.694e+04   1594.057     54.543      0.000    8.38e+04    9.01e+04
# sqft_above       34.1784      1.788     19.117      0.000      30.674      37.683
# sqft_basement    30.0629      2.087     14.406      0.000      25.972      34.153
# yr_built      -2255.4816     50.129    -44.993      0.000   -2353.739   -2157.224
# yr_renovated      3.4944      1.193      2.929      0.003       1.156       5.833
# zipcode        -358.3837     23.546    -15.220      0.000    -404.536    -312.231
# lat            5.666e+05   7520.544     75.346      0.000    5.52e+05    5.81e+05
# long          -1.017e+05   1.06e+04     -9.629      0.000   -1.22e+05    -8.1e+04
# sqft_living15    44.4589      2.739     16.232      0.000      39.090      49.827
# sqft_lot15       -1.3010      0.190     -6.833      0.000      -1.674      -0.928
# ==============================================================================
# Omnibus:                     5060.038   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21916.657
# Skew:                           1.246   Prob(JB):                         0.00
# Kurtosis:                       7.631   Cond. No.                     9.67e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
resid2 = model2.resid
fig = sm.graphics.qqplot(resid2, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model2.resid, bins=100)
# Out:
# (array([3.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00, 3.000e+00, 1.000e+00, 6.000e+00,
#         9.000e+00, 8.000e+00, 1.200e+01, 1.900e+01, 1.400e+01, 2.300e+01,
#         3.500e+01, 5.400e+01, 8.900e+01, 1.140e+02, 1.390e+02, 1.730e+02,
#         2.320e+02, 3.050e+02, 3.600e+02, 4.450e+02, 5.060e+02, 5.890e+02,
#         6.660e+02, 7.360e+02, 8.980e+02, 1.023e+03, 1.008e+03, 1.091e+03,
#         1.100e+03, 1.061e+03, 1.044e+03, 9.490e+02, 8.930e+02, 8.370e+02,
#         7.340e+02, 6.180e+02, 5.140e+02, 4.580e+02, 3.070e+02, 3.080e+02,
#         2.060e+02, 1.790e+02, 1.480e+02, 1.230e+02, 9.900e+01, 8.800e+01,
#         9.100e+01, 6.500e+01, 5.800e+01, 5.100e+01, 3.800e+01, 5.200e+01,
#         3.600e+01, 4.100e+01, 1.800e+01, 3.500e+01, 2.700e+01, 3.200e+01,
#         2.600e+01, 2.300e+01, 1.300e+01, 1.000e+01, 1.100e+01, 1.200e+01,
#         2.100e+01, 1.200e+01, 1.100e+01, 8.000e+00, 1.000e+01, 8.000e+00,
#         1.400e+01, 7.000e+00, 9.000e+00, 6.000e+00, 7.000e+00, 2.000e+00,
#         4.000e+00, 3.000e+00, 8.000e+00, 6.000e+00, 0.000e+00, 2.000e+00,
#         6.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-560988.53471222, -546054.80737112, -531121.08003002,
#         -516187.35268892, -501253.62534782, -486319.89800672,
#         -471386.17066562, -456452.44332452, -441518.71598342,
#         -426584.98864232, -411651.26130123, -396717.53396013,
#         -381783.80661903, -366850.07927793, -351916.35193683,
#         -336982.62459573, -322048.89725463, -307115.16991353,
#         -292181.44257243, -277247.71523133, -262313.98789023,
#         -247380.26054913, -232446.53320803, -217512.80586693,
#         -202579.07852584, -187645.35118474, -172711.62384364,
#         -157777.89650254, -142844.16916144, -127910.44182034,
#         -112976.71447924,  -98042.98713814,  -83109.25979704,
#          -68175.53245594,  -53241.80511484,  -38308.07777374,
#          -23374.35043264,   -8440.62309154,    6493.10424955,
#           21426.83159065,   36360.55893175,   51294.28627285,
#           66228.01361395,   81161.74095505,   96095.46829615,
#          111029.19563725,  125962.92297835,  140896.65031945,
#          155830.37766055,  170764.10500165,  185697.83234275,
#          200631.55968385,  215565.28702494,  230499.01436604,
#          245432.74170714,  260366.46904824,  275300.19638934,
#          290233.92373044,  305167.65107154,  320101.37841264,
#          335035.10575374,  349968.83309484,  364902.56043594,
#          379836.28777704,  394770.01511814,  409703.74245923,
#          424637.46980033,  439571.19714143,  454504.92448253,
#          469438.65182363,  484372.37916473,  499306.10650583,
#          514239.83384693,  529173.56118803,  544107.28852913,
#          559041.01587023,  573974.74321133,  588908.47055243,
#          603842.19789353,  618775.92523462,  633709.65257572,
#          648643.37991682,  663577.10725792,  678510.83459902,
#          693444.56194012,  708378.28928122,  723312.01662232,
#          738245.74396342,  753179.47130452,  768113.19864562,
#          783046.92598672,  797980.65332782,  812914.38066892,
#          827848.10801001,  842781.83535111,  857715.56269221,
#          872649.29003331,  887583.01737441,  902516.74471551,
#          917450.47205661,  932384.19939771]),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(df_no_outliers['price'], model2.resid)
plt.title('Removal of Outliers: Actual Price vs. Residual')
plt.xlabel('Actual Price(Per Million $)')
plt.ylabel('Residual')
plt.show()

# %% [markdown]
# You can see the affect of removing outliers in the dataset by looking at bedrooms:

# %%
sns.boxplot(x='bedrooms', y='price', data=df).set(title='Bedrooms v. Price(in millions $)')
plt.show()

# %%
sns.boxplot(x='bedrooms', y='price', data=df_no_outliers).set(title='Bedrooms v. Price(in millions $)')
plt.show()

# %% [markdown]
# ### Model 3: Dropping insignificant model features

# %% [markdown]
# Based on the results using the DataFrame without outliers, I dropped waterfront and sqft_lot columns since their p-values were greater than 0.05:

# %%
df_no_outliers = df_no_outliers.drop(['waterfront', 'sqft_lot'], axis=1)

# %%
x2 = df_no_outliers.drop('price', axis=1)
y2 = df_no_outliers[['price']]
y2.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
x2.head()
# Out:
#    bedrooms  bathrooms  sqft_living  floors  view  condition  grade  \
# 0         3       1.00         1180     1.0   0.0          3      7
# 1         3       2.25         2570     2.0   0.0          3      7
# 2         2       1.00          770     1.0   0.0          3      6
# 3         4       3.00         1960     1.0   0.0          5      7
# 4         3       2.00         1680     1.0   0.0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0        1180            0.0      1955           0.0    98178  47.5112
# 1        2170          400.0      1951        1991.0    98125  47.7210
# 2         770            0.0      1933        2014.0    98028  47.7379
# 3        1050          910.0      1965           0.0    98136  47.5208
# 4        1680            0.0      1987           0.0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639
# 2 -122.233           2720        8062
# 3 -122.393           1360        5000
# 4 -122.045           1800        7503

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2, random_state=42)

# %%
print(len(x2_train), len(x2_test), len(y2_train), len(y2_test))
# Out:
# 15218 3805 15218 3805

# %%
linreg = LinearRegression()
linreg.fit(x2_train, y2_train)

y2_hat_train = linreg.predict(x2_train)
y2_hat_test = linreg.predict(x2_test)

# %%
third_train_residuals = y2_hat_train - y2_train
third_test_residuals = y2_hat_test - y2_test

# %%
third_train_mse = mean_squared_error(y2_train, y2_hat_train)
third_test_mse = mean_squared_error(y2_test, y2_hat_test)
print('Train Mean Squared Error:', third_train_mse)
print('Test Mean Squared Error:', third_test_mse)
print("Train RMSE: ", third_train_mse**0.5)
print("Test RMSE: ", third_test_mse**0.5)
# Out:
# Train Mean Squared Error: 17576784126.61603
# Test Mean Squared Error: 18408677484.805103
# Train RMSE:  132577.46462584066
# Test RMSE:  135678.58152562293

# %%
f3 = 'price' + '~' + '+'.join(x2.columns)

# %%
# rerun model after dropping columns
model3 = ols(formula=f3, data=df_no_outliers).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     2684.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:19   Log-Likelihood:            -2.5145e+05
# No. Observations:               19023   AIC:                         5.029e+05
# Df Residuals:                   19007   BIC:                         5.031e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -2.281e+05   2.09e+06     -0.109      0.913   -4.32e+06    3.86e+06
# bedrooms      -1.504e+04   1486.331    -10.119      0.000    -1.8e+04   -1.21e+04
# bathrooms      3.038e+04   2429.035     12.506      0.000    2.56e+04    3.51e+04
# sqft_living      64.4362      1.856     34.723      0.000      60.799      68.074
# floors         2.928e+04   2641.908     11.084      0.000    2.41e+04    3.45e+04
# view           4.034e+04   2471.737     16.319      0.000    3.55e+04    4.52e+04
# condition      2.677e+04   1664.578     16.083      0.000    2.35e+04       3e+04
# grade          8.692e+04   1594.063     54.526      0.000    8.38e+04       9e+04
# sqft_above       34.3306      1.786     19.223      0.000      30.830      37.831
# sqft_basement    30.1056      2.087     14.428      0.000      26.016      34.196
# yr_built      -2258.5781     50.099    -45.082      0.000   -2356.777   -2160.379
# yr_renovated      3.4969      1.193      2.931      0.003       1.158       5.836
# zipcode        -359.0775     23.544    -15.251      0.000    -405.226    -312.929
# lat            5.664e+05   7520.097     75.325      0.000    5.52e+05    5.81e+05
# long          -1.012e+05   1.06e+04     -9.587      0.000   -1.22e+05   -8.05e+04
# sqft_living15    44.4147      2.739     16.216      0.000      39.046      49.783
# sqft_lot15       -1.0465      0.119     -8.759      0.000      -1.281      -0.812
# ==============================================================================
# Omnibus:                     5054.264   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21826.489
# Skew:                           1.245   Prob(JB):                         0.00
# Kurtosis:                       7.619   Cond. No.                     4.75e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.21e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
resid3 = model3.resid
fig = sm.graphics.qqplot(resid3, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model3.resid, bins=100)
# Out:
# (array([3.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00, 3.000e+00, 1.000e+00, 5.000e+00,
#         1.000e+01, 6.000e+00, 1.300e+01, 1.900e+01, 1.500e+01, 2.300e+01,
#         3.500e+01, 4.900e+01, 9.200e+01, 1.150e+02, 1.380e+02, 1.660e+02,
#         2.360e+02, 3.040e+02, 3.530e+02, 4.510e+02, 5.020e+02, 5.850e+02,
#         6.680e+02, 7.350e+02, 8.860e+02, 1.023e+03, 1.003e+03, 1.089e+03,
#         1.093e+03, 1.068e+03, 1.035e+03, 9.680e+02, 8.910e+02, 8.270e+02,
#         7.460e+02, 6.290e+02, 5.120e+02, 4.610e+02, 3.100e+02, 3.040e+02,
#         2.090e+02, 1.850e+02, 1.450e+02, 1.210e+02, 1.010e+02, 9.300e+01,
#         8.700e+01, 6.800e+01, 5.700e+01, 5.400e+01, 3.800e+01, 4.800e+01,
#         3.900e+01, 4.100e+01, 1.700e+01, 3.700e+01, 2.500e+01, 3.400e+01,
#         2.500e+01, 2.300e+01, 1.400e+01, 9.000e+00, 1.200e+01, 1.300e+01,
#         2.000e+01, 1.200e+01, 1.100e+01, 8.000e+00, 1.000e+01, 8.000e+00,
#         1.400e+01, 6.000e+00, 1.000e+01, 5.000e+00, 8.000e+00, 2.000e+00,
#         4.000e+00, 3.000e+00, 8.000e+00, 5.000e+00, 1.000e+00, 2.000e+00,
#         5.000e+00, 2.000e+00, 1.000e+00, 2.000e+00, 3.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-561312.75411424, -546381.797197  , -531450.84027975,
#         -516519.88336251, -501588.92644526, -486657.96952802,
#         -471727.01261077, -456796.05569353, -441865.09877629,
#         -426934.14185904, -412003.1849418 , -397072.22802455,
#         -382141.27110731, -367210.31419006, -352279.35727282,
#         -337348.40035557, -322417.44343833, -307486.48652109,
#         -292555.52960384, -277624.5726866 , -262693.61576935,
#         -247762.65885211, -232831.70193486, -217900.74501762,
#         -202969.78810038, -188038.83118313, -173107.87426589,
#         -158176.91734864, -143245.9604314 , -128315.00351415,
#         -113384.04659691,  -98453.08967966,  -83522.13276242,
#          -68591.17584518,  -53660.21892793,  -38729.26201069,
#          -23798.30509344,   -8867.3481762 ,    6063.60874105,
#           20994.56565829,   35925.52257553,   50856.47949278,
#           65787.43641002,   80718.39332727,   95649.35024451,
#          110580.30716176,  125511.264079  ,  140442.22099625,
#          155373.17791349,  170304.13483073,  185235.09174798,
#          200166.04866522,  215097.00558247,  230027.96249971,
#          244958.91941696,  259889.8763342 ,  274820.83325144,
#          289751.79016869,  304682.74708593,  319613.70400318,
#          334544.66092042,  349475.61783767,  364406.57475491,
#          379337.53167216,  394268.4885894 ,  409199.44550664,
#          424130.40242389,  439061.35934113,  453992.31625838,
#          468923.27317562,  483854.23009287,  498785.18701011,
#          513716.14392736,  528647.1008446 ,  543578.05776184,
#          558509.01467909,  573439.97159633,  588370.92851358,
#          603301.88543082,  618232.84234807,  633163.79926531,
#          648094.75618255,  663025.7130998 ,  677956.67001704,
#          692887.62693429,  707818.58385153,  722749.54076878,
#          737680.49768602,  752611.45460327,  767542.41152051,
#          782473.36843775,  797404.325355  ,  812335.28227224,
#          827266.23918949,  842197.19610673,  857128.15302398,
#          872059.10994122,  886990.06685846,  901921.02377571,
#          916851.98069295,  931782.9376102 ]),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(df_no_outliers['price'], model3.resid)

# %% [markdown]
# # Model 4: Creating Dummy Variables

# %% [markdown]
# I decided to create dummy variables for sqft_basement and then rerun the model with the dummy variables:

# %%
df_no_outliers
# Out:
#         price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0      221900         3       1.00         1180     1.0   0.0          3
# 1      538000         3       2.25         2570     2.0   0.0          3
# 2      180000         2       1.00          770     1.0   0.0          3
# 3      604000         4       3.00         1960     1.0   0.0          5
# 4      510000         3       2.00         1680     1.0   0.0          3
# ...       ...       ...        ...          ...     ...   ...        ...
# 21592  360000         3       2.50         1530     3.0   0.0          3
# 21593  400000         4       2.50         2310     2.0   0.0          3
# 21594  402101         2       0.75         1020     2.0   0.0          3
# 21595  400000         3       2.50         1600     2.0   0.0          3
# 21596  325000         2       0.75         1020     2.0   0.0          3
#
#        grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0          7        1180            0.0      1955           0.0    98178
# 1          7        2170          400.0      1951        1991.0    98125
# 2          6         770            0.0      1933        2014.0    98028
# 3          7        1050          910.0      1965           0.0    98136
# 4          8        1680            0.0      1987           0.0    98074
# ...      ...         ...            ...       ...           ...      ...
# 21592      8        1530            0.0      2009           0.0    98103
# 21593      8        2310            0.0      2014           0.0    98146
# 21594      7        1020            0.0      2009           0.0    98144
# 21595      8        1600            0.0      2004           0.0    98027
# 21596      7        1020            0.0      2008           0.0    98144
#
#            lat     long  sqft_living15  sqft_lot15
# 0      47.5112 -122.257           1340        5650
# 1      47.7210 -122.319           1690        7639
# 2      47.7379 -122.233           2720        8062
# 3      47.5208 -122.393           1360        5000
# 4      47.6168 -122.045           1800        7503
# ...        ...      ...            ...         ...
# 21592  47.6993 -122.346           1530        1509
# 21593  47.5107 -122.362           1830        7200
# 21594  47.5944 -122.299           1020        2007
# 21595  47.5345 -122.069           1410        1287
# 21596  47.5941 -122.299           1020        1357
#
# [19023 rows x 17 columns]

# %%
df_no_outliers['sqft_basement'] = df_no_outliers['sqft_basement'].where(df_no_outliers['sqft_basement'] == 0, 1)
df_no_outliers
# Out:
#         price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0      221900         3       1.00         1180     1.0   0.0          3
# 1      538000         3       2.25         2570     2.0   0.0          3
# 2      180000         2       1.00          770     1.0   0.0          3
# 3      604000         4       3.00         1960     1.0   0.0          5
# 4      510000         3       2.00         1680     1.0   0.0          3
# ...       ...       ...        ...          ...     ...   ...        ...
# 21592  360000         3       2.50         1530     3.0   0.0          3
# 21593  400000         4       2.50         2310     2.0   0.0          3
# 21594  402101         2       0.75         1020     2.0   0.0          3
# 21595  400000         3       2.50         1600     2.0   0.0          3
# 21596  325000         2       0.75         1020     2.0   0.0          3
#
#        grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0          7        1180            0.0      1955           0.0    98178
# 1          7        2170            1.0      1951        1991.0    98125
# 2          6         770            0.0      1933        2014.0    98028
# 3          7        1050            1.0      1965           0.0    98136
# 4          8        1680            0.0      1987           0.0    98074
# ...      ...         ...            ...       ...           ...      ...
# 21592      8        1530            0.0      2009           0.0    98103
# 21593      8        2310            0.0      2014           0.0    98146
# 21594      7        1020            0.0      2009           0.0    98144
# 21595      8        1600            0.0      2004           0.0    98027
# 21596      7        1020            0.0      2008           0.0    98144
#
#            lat     long  sqft_living15  sqft_lot15
# 0      47.5112 -122.257           1340        5650
# 1      47.7210 -122.319           1690        7639
# 2      47.7379 -122.233           2720        8062
# 3      47.5208 -122.393           1360        5000
# 4      47.6168 -122.045           1800        7503
# ...        ...      ...            ...         ...
# 21592  47.6993 -122.346           1530        1509
# 21593  47.5107 -122.362           1830        7200
# 21594  47.5944 -122.299           1020        2007
# 21595  47.5345 -122.069           1410        1287
# 21596  47.5941 -122.299           1020        1357
#
# [19023 rows x 17 columns]

# %%
pd.get_dummies(df_no_outliers['sqft_basement'], drop_first=True)
df_no_outliers.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  floors  view  condition  grade  \
# 0  221900         3       1.00         1180     1.0   0.0          3      7
# 1  538000         3       2.25         2570     2.0   0.0          3      7
# 2  180000         2       1.00          770     1.0   0.0          3      6
# 3  604000         4       3.00         1960     1.0   0.0          5      7
# 4  510000         3       2.00         1680     1.0   0.0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0        1180            0.0      1955           0.0    98178  47.5112
# 1        2170            1.0      1951        1991.0    98125  47.7210
# 2         770            0.0      1933        2014.0    98028  47.7379
# 3        1050            1.0      1965           0.0    98136  47.5208
# 4        1680            0.0      1987           0.0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639
# 2 -122.233           2720        8062
# 3 -122.393           1360        5000
# 4 -122.045           1800        7503

# %%
sqbase_dummies = pd.get_dummies(df_no_outliers['sqft_basement'], prefix='sqbase', drop_first=True)
sqbase_dummies
# Out:
#        sqbase_1.0
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0
# ...           ...
# 21592           0
# 21593           0
# 21594           0
# 21595           0
# 21596           0
#
# [19023 rows x 1 columns]

# %%
df_no_outliers = pd.concat([df_no_outliers, sqbase_dummies], axis=1)
df_no_outliers.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  floors  view  condition  grade  \
# 0  221900         3       1.00         1180     1.0   0.0          3      7
# 1  538000         3       2.25         2570     2.0   0.0          3      7
# 2  180000         2       1.00          770     1.0   0.0          3      6
# 3  604000         4       3.00         1960     1.0   0.0          5      7
# 4  510000         3       2.00         1680     1.0   0.0          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0        1180            0.0      1955           0.0    98178  47.5112
# 1        2170            1.0      1951        1991.0    98125  47.7210
# 2         770            0.0      1933        2014.0    98028  47.7379
# 3        1050            1.0      1965           0.0    98136  47.5208
# 4        1680            0.0      1987           0.0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15  sqbase_1.0
# 0 -122.257           1340        5650           0
# 1 -122.319           1690        7639           1
# 2 -122.233           2720        8062           0
# 3 -122.393           1360        5000           1
# 4 -122.045           1800        7503           0

# %%
df_no_outliers = df_no_outliers.drop(['sqft_basement'], axis=1)
df_no_outliers
# Out:
#         price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0      221900         3       1.00         1180     1.0   0.0          3
# 1      538000         3       2.25         2570     2.0   0.0          3
# 2      180000         2       1.00          770     1.0   0.0          3
# 3      604000         4       3.00         1960     1.0   0.0          5
# 4      510000         3       2.00         1680     1.0   0.0          3
# ...       ...       ...        ...          ...     ...   ...        ...
# 21592  360000         3       2.50         1530     3.0   0.0          3
# 21593  400000         4       2.50         2310     2.0   0.0          3
# 21594  402101         2       0.75         1020     2.0   0.0          3
# 21595  400000         3       2.50         1600     2.0   0.0          3
# 21596  325000         2       0.75         1020     2.0   0.0          3
#
#        grade  sqft_above  yr_built  yr_renovated  zipcode      lat     long  \
# 0          7        1180      1955           0.0    98178  47.5112 -122.257
# 1          7        2170      1951        1991.0    98125  47.7210 -122.319
# 2          6         770      1933        2014.0    98028  47.7379 -122.233
# 3          7        1050      1965           0.0    98136  47.5208 -122.393
# 4          8        1680      1987           0.0    98074  47.6168 -122.045
# ...      ...         ...       ...           ...      ...      ...      ...
# 21592      8        1530      2009           0.0    98103  47.6993 -122.346
# 21593      8        2310      2014           0.0    98146  47.5107 -122.362
# 21594      7        1020      2009           0.0    98144  47.5944 -122.299
# 21595      8        1600      2004           0.0    98027  47.5345 -122.069
# 21596      7        1020      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15  sqbase_1.0
# 0               1340        5650           0
# 1               1690        7639           1
# 2               2720        8062           0
# 3               1360        5000           1
# 4               1800        7503           0
# ...              ...         ...         ...
# 21592           1530        1509           0
# 21593           1830        7200           0
# 21594           1020        2007           0
# 21595           1410        1287           0
# 21596           1020        1357           0
#
# [19023 rows x 17 columns]

# %%
df_no_outliers = df_no_outliers.rename(columns={'sqbase_1.0': 'Basement'})
df_no_outliers
# Out:
#         price  bedrooms  bathrooms  sqft_living  floors  view  condition  \
# 0      221900         3       1.00         1180     1.0   0.0          3
# 1      538000         3       2.25         2570     2.0   0.0          3
# 2      180000         2       1.00          770     1.0   0.0          3
# 3      604000         4       3.00         1960     1.0   0.0          5
# 4      510000         3       2.00         1680     1.0   0.0          3
# ...       ...       ...        ...          ...     ...   ...        ...
# 21592  360000         3       2.50         1530     3.0   0.0          3
# 21593  400000         4       2.50         2310     2.0   0.0          3
# 21594  402101         2       0.75         1020     2.0   0.0          3
# 21595  400000         3       2.50         1600     2.0   0.0          3
# 21596  325000         2       0.75         1020     2.0   0.0          3
#
#        grade  sqft_above  yr_built  yr_renovated  zipcode      lat     long  \
# 0          7        1180      1955           0.0    98178  47.5112 -122.257
# 1          7        2170      1951        1991.0    98125  47.7210 -122.319
# 2          6         770      1933        2014.0    98028  47.7379 -122.233
# 3          7        1050      1965           0.0    98136  47.5208 -122.393
# 4          8        1680      1987           0.0    98074  47.6168 -122.045
# ...      ...         ...       ...           ...      ...      ...      ...
# 21592      8        1530      2009           0.0    98103  47.6993 -122.346
# 21593      8        2310      2014           0.0    98146  47.5107 -122.362
# 21594      7        1020      2009           0.0    98144  47.5944 -122.299
# 21595      8        1600      2004           0.0    98027  47.5345 -122.069
# 21596      7        1020      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15  Basement
# 0               1340        5650         0
# 1               1690        7639         1
# 2               2720        8062         0
# 3               1360        5000         1
# 4               1800        7503         0
# ...              ...         ...       ...
# 21592           1530        1509         0
# 21593           1830        7200         0
# 21594           1020        2007         0
# 21595           1410        1287         0
# 21596           1020        1357         0
#
# [19023 rows x 17 columns]

# %%
x3 = df_no_outliers.drop('price', axis=1)
y3 = df_no_outliers[['price']]
y3.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
x3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  floors  view  condition  grade  \
# 0         3       1.00         1180     1.0   0.0          3      7
# 1         3       2.25         2570     2.0   0.0          3      7
# 2         2       1.00          770     1.0   0.0          3      6
# 3         4       3.00         1960     1.0   0.0          5      7
# 4         3       2.00         1680     1.0   0.0          3      8
#
#    sqft_above  yr_built  yr_renovated  zipcode      lat     long  \
# 0        1180      1955           0.0    98178  47.5112 -122.257
# 1        2170      1951        1991.0    98125  47.7210 -122.319
# 2         770      1933        2014.0    98028  47.7379 -122.233
# 3        1050      1965           0.0    98136  47.5208 -122.393
# 4        1680      1987           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  Basement
# 0           1340        5650         0
# 1           1690        7639         1
# 2           2720        8062         0
# 3           1360        5000         1
# 4           1800        7503         0

# %%
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.2, random_state=42)

# %%
print(len(x3_train), len(x3_test), len(y3_train), len(y3_test))
# Out:
# 15218 3805 15218 3805

# %%
linreg = LinearRegression()
linreg.fit(x3_train, y3_train)

y3_hat_train = linreg.predict(x3_train)
y3_hat_test = linreg.predict(x3_test)

# %%
fourth_train_residuals = y3_hat_train - y3_train
fourth_test_residuals = y3_hat_test - y3_test

# %%
fourth_train_mse = mean_squared_error(y3_train, y3_hat_train)
fourth_test_mse = mean_squared_error(y3_test, y3_hat_test)
print('Train Mean Squared Error:', fourth_train_mse)
print('Test Mean Squared Error:', fourth_test_mse)
print("Train RMSE: ", fourth_train_mse**0.5)
print("Test RMSE: ", fourth_test_mse**0.5)
# Out:
# Train Mean Squared Error: 17542497900.277794
# Test Mean Squared Error: 18326219646.02878
# Train RMSE:  132448.0951175886
# Test RMSE:  135374.36849724833

# %%
f4 = 'price' + '~' + '+'.join(x3.columns)

# %%
model4 = ols(formula=f4, data=df_no_outliers).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.680
# Model:                            OLS   Adj. R-squared:                  0.680
# Method:                 Least Squares   F-statistic:                     2526.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:20   Log-Likelihood:            -2.5143e+05
# No. Observations:               19023   AIC:                         5.029e+05
# Df Residuals:                   19006   BIC:                         5.030e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.081e+06   2.09e+06      0.517      0.605   -3.02e+06    5.18e+06
# bedrooms      -1.463e+04   1485.674     -9.849      0.000   -1.75e+04   -1.17e+04
# bathrooms       2.86e+04   2439.604     11.724      0.000    2.38e+04    3.34e+04
# sqft_living      67.7439      5.234     12.943      0.000      57.485      78.003
# floors         2.963e+04   2639.128     11.226      0.000    2.45e+04    3.48e+04
# view           4.039e+04   2468.709     16.359      0.000    3.55e+04    4.52e+04
# condition      2.749e+04   1665.807     16.504      0.000    2.42e+04    3.08e+04
# grade          8.597e+04   1598.039     53.795      0.000    8.28e+04    8.91e+04
# sqft_above       35.2423      5.633      6.256      0.000      24.200      46.284
# yr_built      -2256.5109     50.039    -45.095      0.000   -2354.591   -2158.431
# yr_renovated      3.5464      1.192      2.976      0.003       1.210       5.882
# zipcode        -365.0956     23.531    -15.515      0.000    -411.219    -318.973
# lat            5.647e+05   7515.078     75.143      0.000     5.5e+05    5.79e+05
# long          -9.592e+04   1.06e+04     -9.075      0.000   -1.17e+05   -7.52e+04
# sqft_living15    43.8506      2.737     16.023      0.000      38.486      49.215
# sqft_lot15       -1.0174      0.119     -8.520      0.000      -1.251      -0.783
# Basement       2.763e+04   3995.464      6.915      0.000    1.98e+04    3.55e+04
# ==============================================================================
# Omnibus:                     5119.793   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22337.643
# Skew:                           1.259   Prob(JB):                         0.00
# Kurtosis:                       7.674   Cond. No.                     2.14e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
resid4 = model4.resid
fig = sm.graphics.qqplot(resid4, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model4.resid, bins=100)
# Out:
# (array([3.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 2.000e+00, 4.000e+00, 3.000e+00, 3.000e+00,
#         9.000e+00, 6.000e+00, 1.300e+01, 1.300e+01, 1.300e+01, 2.100e+01,
#         3.700e+01, 4.400e+01, 9.200e+01, 1.220e+02, 1.090e+02, 1.640e+02,
#         2.280e+02, 2.780e+02, 3.440e+02, 4.140e+02, 5.000e+02, 5.680e+02,
#         5.690e+02, 7.440e+02, 8.410e+02, 9.240e+02, 1.018e+03, 1.070e+03,
#         1.099e+03, 1.087e+03, 1.051e+03, 9.770e+02, 8.880e+02, 8.280e+02,
#         7.890e+02, 6.590e+02, 5.510e+02, 4.790e+02, 3.590e+02, 3.020e+02,
#         2.700e+02, 1.860e+02, 1.670e+02, 1.200e+02, 1.080e+02, 8.800e+01,
#         9.800e+01, 8.300e+01, 6.800e+01, 4.100e+01, 5.100e+01, 4.500e+01,
#         4.400e+01, 3.700e+01, 3.500e+01, 1.900e+01, 3.400e+01, 2.700e+01,
#         2.800e+01, 2.900e+01, 2.000e+01, 1.300e+01, 1.000e+01, 1.200e+01,
#         1.100e+01, 2.000e+01, 1.200e+01, 1.300e+01, 8.000e+00, 1.000e+01,
#         9.000e+00, 1.000e+01, 8.000e+00, 9.000e+00, 5.000e+00, 9.000e+00,
#         2.000e+00, 4.000e+00, 2.000e+00, 8.000e+00, 4.000e+00, 3.000e+00,
#         1.000e+00, 5.000e+00, 3.000e+00, 1.000e+00, 1.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([-5.58245649e+05, -5.43538190e+05, -5.28830731e+05, -5.14123272e+05,
#         -4.99415812e+05, -4.84708353e+05, -4.70000894e+05, -4.55293434e+05,
#         -4.40585975e+05, -4.25878516e+05, -4.11171057e+05, -3.96463597e+05,
#         -3.81756138e+05, -3.67048679e+05, -3.52341219e+05, -3.37633760e+05,
#         -3.22926301e+05, -3.08218841e+05, -2.93511382e+05, -2.78803923e+05,
#         -2.64096464e+05, -2.49389004e+05, -2.34681545e+05, -2.19974086e+05,
#         -2.05266626e+05, -1.90559167e+05, -1.75851708e+05, -1.61144249e+05,
#         -1.46436789e+05, -1.31729330e+05, -1.17021871e+05, -1.02314411e+05,
#         -8.76069520e+04, -7.28994927e+04, -5.81920334e+04, -4.34845742e+04,
#         -2.87771149e+04, -1.40696556e+04,  6.37803731e+02,  1.53452630e+04,
#          3.00527223e+04,  4.47601816e+04,  5.94676409e+04,  7.41751002e+04,
#          8.88825595e+04,  1.03590019e+05,  1.18297478e+05,  1.33004937e+05,
#          1.47712397e+05,  1.62419856e+05,  1.77127315e+05,  1.91834775e+05,
#          2.06542234e+05,  2.21249693e+05,  2.35957152e+05,  2.50664612e+05,
#          2.65372071e+05,  2.80079530e+05,  2.94786990e+05,  3.09494449e+05,
#          3.24201908e+05,  3.38909367e+05,  3.53616827e+05,  3.68324286e+05,
#          3.83031745e+05,  3.97739205e+05,  4.12446664e+05,  4.27154123e+05,
#          4.41861583e+05,  4.56569042e+05,  4.71276501e+05,  4.85983960e+05,
#          5.00691420e+05,  5.15398879e+05,  5.30106338e+05,  5.44813798e+05,
#          5.59521257e+05,  5.74228716e+05,  5.88936176e+05,  6.03643635e+05,
#          6.18351094e+05,  6.33058553e+05,  6.47766013e+05,  6.62473472e+05,
#          6.77180931e+05,  6.91888391e+05,  7.06595850e+05,  7.21303309e+05,
#          7.36010768e+05,  7.50718228e+05,  7.65425687e+05,  7.80133146e+05,
#          7.94840606e+05,  8.09548065e+05,  8.24255524e+05,  8.38962984e+05,
#          8.53670443e+05,  8.68377902e+05,  8.83085361e+05,  8.97792821e+05,
#          9.12500280e+05]),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(df_no_outliers['price'], model4.resid)

# %% [markdown]
# # Model 5: Multicollinearity Check

# %% [markdown]
# At this point, I decided to do a multicollinearity check to see if I needed to drop additional features:

# %%
df_no_outliers.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living    floors      view  \
# price          1.000000  0.301760   0.448940     0.621542  0.277033  0.191522
# bedrooms       0.301760  1.000000   0.492129     0.607741  0.165752  0.040141
# bathrooms      0.448940  0.492129   1.000000     0.711381  0.517288  0.072481
# sqft_living    0.621542  0.607741   0.711381     1.000000  0.360391  0.129675
# floors         0.277033  0.165752   0.517288     0.360391  1.000000 -0.011150
# view           0.191522  0.040141   0.072481     0.129675 -0.011150  1.000000
# condition      0.039140  0.020068  -0.146403    -0.076914 -0.281064  0.029337
# grade          0.632251  0.332925   0.616455     0.706350  0.472161  0.108750
# sqft_above     0.527170  0.484463   0.630039     0.855538  0.540140  0.048839
# yr_built       0.038329  0.167878   0.549460     0.348033  0.508997 -0.067526
# yr_renovated   0.037001 -0.009576  -0.001192     0.003022 -0.007631  0.016083
# zipcode       -0.032571 -0.168929  -0.217138    -0.214735 -0.061832  0.087347
# lat            0.426847 -0.037810   0.001431     0.035278  0.039121  0.011292
# long           0.057398  0.173701   0.270213     0.301064  0.144284 -0.079744
# sqft_living15  0.542083  0.395927   0.527379     0.737635  0.276984  0.145345
# sqft_lot15     0.085880  0.106434   0.060781     0.226493 -0.104732  0.018873
# Basement       0.160872  0.140584   0.134187     0.171190 -0.277332  0.132731
#
#                condition     grade  sqft_above  yr_built  yr_renovated  \
# price           0.039140  0.632251    0.527170  0.038329      0.037001
# bedrooms        0.020068  0.332925    0.484463  0.167878     -0.009576
# bathrooms      -0.146403  0.616455    0.630039  0.549460     -0.001192
# sqft_living    -0.076914  0.706350    0.855538  0.348033      0.003022
# floors         -0.281064  0.472161    0.540140  0.508997     -0.007631
# view            0.029337  0.108750    0.048839 -0.067526      0.016083
# condition       1.000000 -0.179602   -0.180251 -0.369240     -0.027708
# grade          -0.179602  1.000000    0.710321  0.479040     -0.007482
# sqft_above     -0.180251  0.710321    1.000000  0.455191     -0.005353
# yr_built       -0.369240  0.479040    0.455191  1.000000     -0.085021
# yr_renovated   -0.027708 -0.007482   -0.005353 -0.085021      1.000000
# zipcode        -0.007501 -0.191109   -0.277936 -0.341373      0.029456
# lat            -0.014390  0.106874   -0.024970 -0.156718      0.021454
# long           -0.091351  0.241395    0.407357  0.427830     -0.028676
# sqft_living15  -0.113324  0.669421    0.719944  0.351043     -0.020755
# sqft_lot15      0.053932  0.150446    0.219649  0.045953      0.004960
# Basement        0.124778  0.000549   -0.289189 -0.171325      0.013127
#
#                 zipcode       lat      long  sqft_living15  sqft_lot15  \
# price         -0.032571  0.426847  0.057398       0.542083    0.085880
# bedrooms      -0.168929 -0.037810  0.173701       0.395927    0.106434
# bathrooms     -0.217138  0.001431  0.270213       0.527379    0.060781
# sqft_living   -0.214735  0.035278  0.301064       0.737635    0.226493
# floors        -0.061832  0.039121  0.144284       0.276984   -0.104732
# view           0.087347  0.011292 -0.079744       0.145345    0.018873
# condition     -0.007501 -0.014390 -0.091351      -0.113324    0.053932
# grade         -0.191109  0.106874  0.241395       0.669421    0.150446
# sqft_above    -0.277936 -0.024970  0.407357       0.719944    0.219649
# yr_built      -0.341373 -0.156718  0.427830       0.351043    0.045953
# yr_renovated   0.029456  0.021454 -0.028676      -0.020755    0.004960
# zipcode        1.000000  0.280849 -0.580782      -0.300425   -0.196065
# lat            0.280849  1.000000 -0.133595       0.033393   -0.054747
# long          -0.580782 -0.133595  1.000000       0.405968    0.307936
# sqft_living15 -0.300425  0.033393  0.405968       1.000000    0.295954
# sqft_lot15    -0.196065 -0.054747  0.307936       0.295954    1.000000
# Basement       0.164215  0.135801 -0.245619      -0.008582   -0.044278
#
#                Basement
# price          0.160872
# bedrooms       0.140584
# bathrooms      0.134187
# sqft_living    0.171190
# floors        -0.277332
# view           0.132731
# condition      0.124778
# grade          0.000549
# sqft_above    -0.289189
# yr_built      -0.171325
# yr_renovated   0.013127
# zipcode        0.164215
# lat            0.135801
# long          -0.245619
# sqft_living15 -0.008582
# sqft_lot15    -0.044278
# Basement       1.000000

# %%
abs(df_no_outliers.corr()) > 0.70
# Out:
#                price  bedrooms  bathrooms  sqft_living  floors   view  \
# price           True     False      False        False   False  False
# bedrooms       False      True      False        False   False  False
# bathrooms      False     False       True         True   False  False
# sqft_living    False     False       True         True   False  False
# floors         False     False      False        False    True  False
# view           False     False      False        False   False   True
# condition      False     False      False        False   False  False
# grade          False     False      False         True   False  False
# sqft_above     False     False      False         True   False  False
# yr_built       False     False      False        False   False  False
# yr_renovated   False     False      False        False   False  False
# zipcode        False     False      False        False   False  False
# lat            False     False      False        False   False  False
# long           False     False      False        False   False  False
# sqft_living15  False     False      False         True   False  False
# sqft_lot15     False     False      False        False   False  False
# Basement       False     False      False        False   False  False
#
#                condition  grade  sqft_above  yr_built  yr_renovated  zipcode  \
# price              False  False       False     False         False    False
# bedrooms           False  False       False     False         False    False
# bathrooms          False  False       False     False         False    False
# sqft_living        False   True        True     False         False    False
# floors             False  False       False     False         False    False
# view               False  False       False     False         False    False
# condition           True  False       False     False         False    False
# grade              False   True        True     False         False    False
# sqft_above         False   True        True     False         False    False
# yr_built           False  False       False      True         False    False
# yr_renovated       False  False       False     False          True    False
# zipcode            False  False       False     False         False     True
# lat                False  False       False     False         False    False
# long               False  False       False     False         False    False
# sqft_living15      False  False        True     False         False    False
# sqft_lot15         False  False       False     False         False    False
# Basement           False  False       False     False         False    False
#
#                  lat   long  sqft_living15  sqft_lot15  Basement
# price          False  False          False       False     False
# bedrooms       False  False          False       False     False
# bathrooms      False  False          False       False     False
# sqft_living    False  False           True       False     False
# floors         False  False          False       False     False
# view           False  False          False       False     False
# condition      False  False          False       False     False
# grade          False  False          False       False     False
# sqft_above     False  False           True       False     False
# yr_built       False  False          False       False     False
# yr_renovated   False  False          False       False     False
# zipcode        False  False          False       False     False
# lat             True  False          False       False     False
# long           False   True          False       False     False
# sqft_living15  False  False           True       False     False
# sqft_lot15     False  False          False        True     False
# Basement       False  False          False       False      True

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_no_outliers.corr(), annot=True, center=0);

# %%
sm1 = pd.plotting.scatter_matrix(df_no_outliers, figsize=[20, 20]);

[s.xaxis.label.set_rotation(90) for s in sm1.reshape(-1)]
[s.yaxis.label.set_rotation(0) for s in sm1.reshape(-1)]

[s.get_yaxis().set_label_coords(-1,0.5) for s in sm1.reshape(-1)]

[s.set_xticks(()) for s in sm1.reshape(-1)]
[s.set_yticks(()) for s in sm1.reshape(-1)]

plt.show()

# %%
df_corr = df_no_outliers.corr().abs().stack().reset_index().sort_values(0, ascending=False)

df_corr['pairs'] = list(zip(df_corr.level_0, df_corr.level_1))

df_corr.set_index(['pairs'], inplace = True)

df_corr.drop(columns=['level_1', 'level_0'], inplace = True)

# cc for correlation coefficient
df_corr.columns = ['cc']

df_corr.drop_duplicates(inplace=True)

df_corr[(df_corr.cc>.70) & (df_corr.cc<1)]
# Out:
#                                     cc
# pairs
# (sqft_above, sqft_living)     0.855538
# (sqft_living15, sqft_living)  0.737635
# (sqft_living15, sqft_above)   0.719944
# (bathrooms, sqft_living)      0.711381
# (sqft_above, grade)           0.710321
# (grade, sqft_living)          0.706350

# %% [markdown]
# Based on the results of the multicollinearity check, I decided to drop features that had high correlations with sqft_living, since sqft_living has a high coefficient correlation with price.

# %%
df_no_outliers.drop(columns=['sqft_above', 'sqft_living15', 'bathrooms', 'grade'], inplace=True)
df_no_outliers
# Out:
#         price  bedrooms  sqft_living  floors  view  condition  yr_built  \
# 0      221900         3         1180     1.0   0.0          3      1955
# 1      538000         3         2570     2.0   0.0          3      1951
# 2      180000         2          770     1.0   0.0          3      1933
# 3      604000         4         1960     1.0   0.0          5      1965
# 4      510000         3         1680     1.0   0.0          3      1987
# ...       ...       ...          ...     ...   ...        ...       ...
# 21592  360000         3         1530     3.0   0.0          3      2009
# 21593  400000         4         2310     2.0   0.0          3      2014
# 21594  402101         2         1020     2.0   0.0          3      2009
# 21595  400000         3         1600     2.0   0.0          3      2004
# 21596  325000         2         1020     2.0   0.0          3      2008
#
#        yr_renovated  zipcode      lat     long  sqft_lot15  Basement
# 0               0.0    98178  47.5112 -122.257        5650         0
# 1            1991.0    98125  47.7210 -122.319        7639         1
# 2            2014.0    98028  47.7379 -122.233        8062         0
# 3               0.0    98136  47.5208 -122.393        5000         1
# 4               0.0    98074  47.6168 -122.045        7503         0
# ...             ...      ...      ...      ...         ...       ...
# 21592           0.0    98103  47.6993 -122.346        1509         0
# 21593           0.0    98146  47.5107 -122.362        7200         0
# 21594           0.0    98144  47.5944 -122.299        2007         0
# 21595           0.0    98027  47.5345 -122.069        1287         0
# 21596           0.0    98144  47.5941 -122.299        1357         0
#
# [19023 rows x 13 columns]

# %%
x4 = df_no_outliers.drop('price', axis=1)
y4 = df_no_outliers[['price']]
y4.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
x4.head()
# Out:
#    bedrooms  sqft_living  floors  view  condition  yr_built  yr_renovated  \
# 0         3         1180     1.0   0.0          3      1955           0.0
# 1         3         2570     2.0   0.0          3      1951        1991.0
# 2         2          770     1.0   0.0          3      1933        2014.0
# 3         4         1960     1.0   0.0          5      1965           0.0
# 4         3         1680     1.0   0.0          3      1987           0.0
#
#    zipcode      lat     long  sqft_lot15  Basement
# 0    98178  47.5112 -122.257        5650         0
# 1    98125  47.7210 -122.319        7639         1
# 2    98028  47.7379 -122.233        8062         0
# 3    98136  47.5208 -122.393        5000         1
# 4    98074  47.6168 -122.045        7503         0

# %%
x4_train, x4_test, y4_train, y4_test = train_test_split(x4, y4, test_size=0.2, random_state=42)

# %%
print(len(x4_train), len(x4_test), len(y4_train), len(y4_test))
# Out:
# 15218 3805 15218 3805

# %%
linreg = LinearRegression()
linreg.fit(x4_train, y4_train)

y4_hat_train = linreg.predict(x4_train)
y4_hat_test = linreg.predict(x4_test)

# %%
fifth_train_residuals = y4_hat_train - y4_train
fifth_test_residuals = y4_hat_test - y4_test

# %%
fifth_train_mse = mean_squared_error(y4_train, y4_hat_train)
fifth_test_mse = mean_squared_error(y4_test, y4_hat_test)
print('Train Mean Squared Error:', fifth_train_mse)
print('Test Mean Squared Error:', fifth_test_mse)
print("Train RMSE: ", fifth_train_mse**0.5)
print("Test RMSE: ", fifth_test_mse**0.5)
# Out:
# Train Mean Squared Error: 21733532028.704975
# Test Mean Squared Error: 22598913992.783546
# Train RMSE:  147422.96981374704
# Test RMSE:  150329.35173406271

# %%
f5 = 'price' + '~' + '+'.join(x4.columns)

# %%
model5 = ols(formula=f5, data=df_no_outliers).fit()

# %%
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     2417.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:41   Log-Likelihood:            -2.5346e+05
# No. Observations:               19023   AIC:                         5.069e+05
# Df Residuals:                   19010   BIC:                         5.070e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     5.083e+06   2.29e+06      2.220      0.026    5.96e+05    9.57e+06
# bedrooms     -2.569e+04   1611.249    -15.947      0.000   -2.89e+04   -2.25e+04
# sqft_living    211.1900      2.193     96.287      0.000     206.891     215.489
# floors         6.23e+04   2666.189     23.365      0.000    5.71e+04    6.75e+04
# view          5.685e+04   2713.863     20.946      0.000    5.15e+04    6.22e+04
# condition     2.507e+04   1837.122     13.645      0.000    2.15e+04    2.87e+04
# yr_built     -1304.4565     50.799    -25.679      0.000   -1404.027   -1204.886
# yr_renovated     4.2385      1.324      3.202      0.001       1.644       6.833
# zipcode       -511.7821     26.009    -19.677      0.000    -562.762    -460.802
# lat            6.57e+05   8199.277     80.131      0.000    6.41e+05    6.73e+05
# long         -1.343e+05   1.15e+04    -11.660      0.000   -1.57e+05   -1.12e+05
# sqft_lot15      -0.4363      0.131     -3.319      0.001      -0.694      -0.179
# Basement     -1235.9780   2593.806     -0.477      0.634   -6320.069    3848.113
# ==============================================================================
# Omnibus:                     4595.632   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17979.118
# Skew:                           1.159   Prob(JB):                         0.00
# Kurtosis:                       7.161   Cond. No.                     2.10e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.1e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
resid5 = model5.resid
fig = sm.graphics.qqplot(resid5, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model5.resid, bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 3.000e+00, 8.000e+00,
#         5.000e+00, 4.000e+00, 1.000e+01, 1.000e+01, 1.300e+01, 3.200e+01,
#         2.500e+01, 3.200e+01, 5.000e+01, 5.400e+01, 7.100e+01, 1.030e+02,
#         1.490e+02, 1.970e+02, 2.160e+02, 2.530e+02, 3.680e+02, 4.380e+02,
#         5.580e+02, 5.700e+02, 6.980e+02, 7.680e+02, 8.860e+02, 9.510e+02,
#         9.300e+02, 1.033e+03, 1.044e+03, 1.096e+03, 1.074e+03, 1.042e+03,
#         9.470e+02, 8.250e+02, 6.990e+02, 6.080e+02, 5.140e+02, 3.680e+02,
#         3.320e+02, 2.710e+02, 2.460e+02, 1.860e+02, 1.580e+02, 1.250e+02,
#         1.180e+02, 1.040e+02, 7.800e+01, 7.400e+01, 5.000e+01, 5.800e+01,
#         5.400e+01, 4.600e+01, 4.400e+01, 4.800e+01, 3.300e+01, 1.700e+01,
#         3.000e+01, 2.700e+01, 2.700e+01, 2.200e+01, 2.200e+01, 1.700e+01,
#         1.600e+01, 1.800e+01, 1.500e+01, 1.100e+01, 1.200e+01, 1.000e+01,
#         1.100e+01, 7.000e+00, 2.000e+00, 9.000e+00, 9.000e+00, 1.000e+01,
#         1.300e+01, 4.000e+00, 5.000e+00, 6.000e+00, 5.000e+00, 2.000e+00,
#         3.000e+00, 3.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 2.000e+00, 1.000e+00]),
#  array([-647466.93527231, -631119.21379743, -614771.49232255,
#         -598423.77084766, -582076.04937278, -565728.32789789,
#         -549380.60642301, -533032.88494812, -516685.16347324,
#         -500337.44199836, -483989.72052347, -467641.99904859,
#         -451294.2775737 , -434946.55609882, -418598.83462394,
#         -402251.11314905, -385903.39167417, -369555.67019928,
#         -353207.9487244 , -336860.22724952, -320512.50577463,
#         -304164.78429975, -287817.06282486, -271469.34134998,
#         -255121.61987509, -238773.89840021, -222426.17692533,
#         -206078.45545044, -189730.73397556, -173383.01250067,
#         -157035.29102579, -140687.56955091, -124339.84807602,
#         -107992.12660114,  -91644.40512625,  -75296.68365137,
#          -58948.96217649,  -42601.2407016 ,  -26253.51922672,
#           -9905.79775183,    6441.92372305,   22789.64519794,
#           39137.36667282,   55485.0881477 ,   71832.80962259,
#           88180.53109747,  104528.25257236,  120875.97404724,
#          137223.69552212,  153571.41699701,  169919.13847189,
#          186266.85994678,  202614.58142166,  218962.30289654,
#          235310.02437143,  251657.74584631,  268005.4673212 ,
#          284353.18879608,  300700.91027096,  317048.63174585,
#          333396.35322073,  349744.07469562,  366091.7961705 ,
#          382439.51764539,  398787.23912027,  415134.96059515,
#          431482.68207004,  447830.40354492,  464178.12501981,
#          480525.84649469,  496873.56796957,  513221.28944446,
#          529569.01091934,  545916.73239423,  562264.45386911,
#          578612.17534399,  594959.89681888,  611307.61829376,
#          627655.33976865,  644003.06124353,  660350.78271842,
#          676698.5041933 ,  693046.22566818,  709393.94714307,
#          725741.66861795,  742089.39009284,  758437.11156772,
#          774784.8330426 ,  791132.55451749,  807480.27599237,
#          823827.99746726,  840175.71894214,  856523.44041702,
#          872871.16189191,  889218.88336679,  905566.60484168,
#          921914.32631656,  938262.04779145,  954609.76926633,
#          970957.49074121,  987305.2122161 ]),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(df_no_outliers['price'], model5.resid)

# %% [markdown]
# # Model 6: Log Transforming Features

# %%
data_log = pd.DataFrame([])
data_log['logbed'] = np.log(df_no_outliers['bedrooms'])
data_log['logsqliv'] = np.log(df_no_outliers['sqft_living'])
data_log['logfloors'] = np.log(df_no_outliers['floors'])
data_log.hist(figsize  = [10, 10]);

# %%
df_combo = df_no_outliers.merge(data_log, left_index=True, right_index=True)

# %%
df_combo
# Out:
#         price  bedrooms  sqft_living  floors  view  condition  yr_built  \
# 0      221900         3         1180     1.0   0.0          3      1955
# 1      538000         3         2570     2.0   0.0          3      1951
# 2      180000         2          770     1.0   0.0          3      1933
# 3      604000         4         1960     1.0   0.0          5      1965
# 4      510000         3         1680     1.0   0.0          3      1987
# ...       ...       ...          ...     ...   ...        ...       ...
# 21592  360000         3         1530     3.0   0.0          3      2009
# 21593  400000         4         2310     2.0   0.0          3      2014
# 21594  402101         2         1020     2.0   0.0          3      2009
# 21595  400000         3         1600     2.0   0.0          3      2004
# 21596  325000         2         1020     2.0   0.0          3      2008
#
#        yr_renovated  zipcode      lat     long  sqft_lot15  Basement  \
# 0               0.0    98178  47.5112 -122.257        5650         0
# 1            1991.0    98125  47.7210 -122.319        7639         1
# 2            2014.0    98028  47.7379 -122.233        8062         0
# 3               0.0    98136  47.5208 -122.393        5000         1
# 4               0.0    98074  47.6168 -122.045        7503         0
# ...             ...      ...      ...      ...         ...       ...
# 21592           0.0    98103  47.6993 -122.346        1509         0
# 21593           0.0    98146  47.5107 -122.362        7200         0
# 21594           0.0    98144  47.5944 -122.299        2007         0
# 21595           0.0    98027  47.5345 -122.069        1287         0
# 21596           0.0    98144  47.5941 -122.299        1357         0
#
#          logbed  logsqliv  logfloors
# 0      1.098612  7.073270   0.000000
# 1      1.098612  7.851661   0.693147
# 2      0.693147  6.646391   0.000000
# 3      1.386294  7.580700   0.000000
# 4      1.098612  7.426549   0.000000
# ...         ...       ...        ...
# 21592  1.098612  7.333023   1.098612
# 21593  1.386294  7.745003   0.693147
# 21594  0.693147  6.927558   0.693147
# 21595  1.098612  7.377759   0.693147
# 21596  0.693147  6.927558   0.693147
#
# [19023 rows x 16 columns]

# %%
x5 = df_combo.drop('price', axis=1)
y5 = df_combo[['price']]
y5.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
x5.head()
# Out:
#    bedrooms  sqft_living  floors  view  condition  yr_built  yr_renovated  \
# 0         3         1180     1.0   0.0          3      1955           0.0
# 1         3         2570     2.0   0.0          3      1951        1991.0
# 2         2          770     1.0   0.0          3      1933        2014.0
# 3         4         1960     1.0   0.0          5      1965           0.0
# 4         3         1680     1.0   0.0          3      1987           0.0
#
#    zipcode      lat     long  sqft_lot15  Basement    logbed  logsqliv  \
# 0    98178  47.5112 -122.257        5650         0  1.098612  7.073270
# 1    98125  47.7210 -122.319        7639         1  1.098612  7.851661
# 2    98028  47.7379 -122.233        8062         0  0.693147  6.646391
# 3    98136  47.5208 -122.393        5000         1  1.386294  7.580700
# 4    98074  47.6168 -122.045        7503         0  1.098612  7.426549
#
#    logfloors
# 0   0.000000
# 1   0.693147
# 2   0.000000
# 3   0.000000
# 4   0.000000

# %%
x5_train, x5_test, y5_train, y5_test = train_test_split(x5, y5, test_size=0.2, random_state=42)

# %%
print(len(x5_train), len(x5_test), len(y5_train), len(y5_test))
# Out:
# 15218 3805 15218 3805

# %%
linreg = LinearRegression()
linreg.fit(x5_train, y5_train)

y5_hat_train = linreg.predict(x5_train)
y5_hat_test = linreg.predict(x5_test)

# %%
sixth_train_residuals = y5_hat_train - y5_train
sixth_test_residuals = y5_hat_test - y5_test

# %%
sixth_train_mse = mean_squared_error(y5_train, y5_hat_train)
sixth_test_mse = mean_squared_error(y5_test, y5_hat_test)
print('Train Mean Squared Error:', sixth_train_mse)
print('Test Mean Squared Error:', sixth_test_mse)
print("Train RMSE: ", sixth_train_mse**0.5)
print("Test RMSE: ", sixth_test_mse**0.5)
# Out:
# Train Mean Squared Error: 21547663563.31945
# Test Mean Squared Error: 22566339887.40271
# Train RMSE:  146791.2244084075
# Test RMSE:  150220.97019858015

# %%
f6 = 'price' + '~' + '+'.join(x5.columns)

# %%
model6 = ols(formula=f6, data=df_combo).fit()

# %%
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.607
# Method:                 Least Squares   F-statistic:                     1956.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:41   Log-Likelihood:            -2.5339e+05
# No. Observations:               19023   AIC:                         5.068e+05
# Df Residuals:                   19007   BIC:                         5.069e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     8.024e+06   2.31e+06      3.473      0.001     3.5e+06    1.26e+07
# bedrooms     -5.322e+04   6279.117     -8.476      0.000   -6.55e+04   -4.09e+04
# sqft_living    285.6303      6.864     41.613      0.000     272.176     299.084
# floors        2.987e+04   1.63e+04      1.828      0.068   -2151.304    6.19e+04
# view           5.65e+04   2705.331     20.885      0.000    5.12e+04    6.18e+04
# condition      2.61e+04   1839.145     14.190      0.000    2.25e+04    2.97e+04
# yr_built     -1258.0351     52.487    -23.969      0.000   -1360.914   -1155.157
# yr_renovated     4.4264      1.319      3.355      0.001       1.840       7.013
# zipcode       -530.9794     26.003    -20.420      0.000    -581.948    -480.011
# lat           6.583e+05   8222.027     80.063      0.000    6.42e+05    6.74e+05
# long          -1.33e+05   1.16e+04    -11.451      0.000   -1.56e+05    -1.1e+05
# sqft_lot15      -0.4510      0.131     -3.436      0.001      -0.708      -0.194
# Basement      7251.6629   2693.797      2.692      0.007    1971.582    1.25e+04
# logbed         1.04e+05   1.99e+04      5.218      0.000    6.49e+04    1.43e+05
# logsqliv     -1.605e+05   1.39e+04    -11.584      0.000   -1.88e+05   -1.33e+05
# logfloors     5.562e+04   2.51e+04      2.220      0.026    6505.981    1.05e+05
# ==============================================================================
# Omnibus:                     4605.383   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18476.484
# Skew:                           1.153   Prob(JB):                         0.00
# Kurtosis:                       7.242   Cond. No.                     2.13e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
resid6 = model6.resid
fig = sm.graphics.qqplot(resid6, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model6.resid, bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 3.000e+00,
#         2.000e+00, 3.000e+00, 6.000e+00, 6.000e+00, 9.000e+00, 8.000e+00,
#         1.400e+01, 1.700e+01, 2.700e+01, 3.100e+01, 3.900e+01, 5.500e+01,
#         6.700e+01, 7.300e+01, 1.200e+02, 1.560e+02, 2.120e+02, 2.490e+02,
#         3.230e+02, 4.470e+02, 5.140e+02, 6.130e+02, 6.850e+02, 8.150e+02,
#         9.650e+02, 9.770e+02, 1.019e+03, 1.084e+03, 1.113e+03, 1.214e+03,
#         1.122e+03, 1.080e+03, 9.430e+02, 8.050e+02, 6.630e+02, 5.710e+02,
#         4.500e+02, 3.390e+02, 3.200e+02, 2.560e+02, 2.220e+02, 1.790e+02,
#         1.400e+02, 1.250e+02, 1.000e+02, 9.500e+01, 6.200e+01, 7.500e+01,
#         4.400e+01, 6.700e+01, 4.800e+01, 4.100e+01, 4.600e+01, 2.700e+01,
#         3.500e+01, 2.500e+01, 2.600e+01, 2.800e+01, 2.200e+01, 2.400e+01,
#         1.400e+01, 1.400e+01, 1.400e+01, 1.600e+01, 1.100e+01, 1.100e+01,
#         9.000e+00, 4.000e+00, 1.200e+01, 7.000e+00, 5.000e+00, 1.100e+01,
#         8.000e+00, 7.000e+00, 6.000e+00, 6.000e+00, 4.000e+00, 2.000e+00,
#         2.000e+00, 3.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 2.000e+00, 1.000e+00]),
#  array([-710537.11409321, -693387.23150916, -676237.3489251 ,
#         -659087.46634105, -641937.58375699, -624787.70117294,
#         -607637.81858888, -590487.93600483, -573338.05342077,
#         -556188.17083672, -539038.28825267, -521888.40566861,
#         -504738.52308456, -487588.6405005 , -470438.75791645,
#         -453288.87533239, -436138.99274834, -418989.11016428,
#         -401839.22758023, -384689.34499617, -367539.46241212,
#         -350389.57982807, -333239.69724401, -316089.81465996,
#         -298939.9320759 , -281790.04949185, -264640.16690779,
#         -247490.28432374, -230340.40173968, -213190.51915563,
#         -196040.63657157, -178890.75398752, -161740.87140347,
#         -144590.98881941, -127441.10623536, -110291.2236513 ,
#          -93141.34106725,  -75991.45848319,  -58841.57589914,
#          -41691.69331508,  -24541.81073103,   -7391.92814697,
#            9757.95443708,   26907.83702113,   44057.71960519,
#           61207.60218924,   78357.4847733 ,   95507.36735735,
#          112657.24994141,  129807.13252546,  146957.01510952,
#          164106.89769357,  181256.78027763,  198406.66286168,
#          215556.54544573,  232706.42802979,  249856.31061384,
#          267006.1931979 ,  284156.07578195,  301305.95836601,
#          318455.84095006,  335605.72353412,  352755.60611817,
#          369905.48870223,  387055.37128628,  404205.25387033,
#          421355.13645439,  438505.01903844,  455654.9016225 ,
#          472804.78420655,  489954.66679061,  507104.54937466,
#          524254.43195872,  541404.31454277,  558554.19712683,
#          575704.07971088,  592853.96229493,  610003.84487899,
#          627153.72746304,  644303.6100471 ,  661453.49263115,
#          678603.37521521,  695753.25779926,  712903.14038332,
#          730053.02296737,  747202.90555143,  764352.78813548,
#          781502.67071953,  798652.55330359,  815802.43588764,
#          832952.3184717 ,  850102.20105575,  867252.08363981,
#          884401.96622386,  901551.84880792,  918701.73139197,
#          935851.61397603,  953001.49656008,  970151.37914413,
#          987301.26172819, 1004451.14431224]),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(df_combo['price'], model6.resid)

# %% [markdown]
# # Model 7: Feature Scaling

# %% [markdown]
# Based on the the results from the previous model, I decided to scale the transformed features to see if that would increase the R-square and decrease the RMSE:

# %%
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_combo), columns = df_combo.columns)
df_scaled.head()
# Out:
#       price  bedrooms  sqft_living    floors      view  condition  yr_built  \
# 0 -1.120253 -0.382310    -1.047777 -0.893509 -0.232215  -0.644011 -0.530899
# 1  0.223724 -0.382310     0.833589  0.965432 -0.232215  -0.644011 -0.666977
# 2 -1.298401 -1.558929    -1.602712 -0.893509 -0.232215  -0.644011 -1.279328
# 3  0.504339  0.794309     0.007953 -0.893509 -0.232215   2.459870 -0.190704
# 4  0.104675 -0.382310    -0.371027 -0.893509 -0.232215  -0.644011  0.557724
#
#    yr_renovated   zipcode       lat      long  sqft_lot15  Basement    logbed  \
# 0     -0.512646  1.852530 -0.358097 -0.270092   -0.382516 -0.783865 -0.247469
# 1      1.925604  0.860806  1.142074 -0.752738   -0.160909  1.275730 -0.247469
# 2      1.953771 -0.954235  1.262917 -0.083262   -0.113780 -0.783865 -1.729579
# 3     -0.512646  1.066636 -0.289453 -1.328799   -0.454937  1.275730  0.804104
# 4     -0.512646 -0.093494  0.396994  1.380244   -0.176062 -0.783865 -0.247469
#
#    logsqliv  logfloors
# 0 -1.113191  -0.937308
# 1  0.893865   1.035129
# 2 -2.213885  -0.937308
# 3  0.195200  -0.937308
# 4 -0.202272  -0.937308

# %%
x6 = df_scaled.drop('price', axis=1)
y6 = df_scaled[['price']]
y6.head()
# Out:
#       price
# 0 -1.120253
# 1  0.223724
# 2 -1.298401
# 3  0.504339
# 4  0.104675

# %%
x6.head()
# Out:
#    bedrooms  sqft_living    floors      view  condition  yr_built  \
# 0 -0.382310    -1.047777 -0.893509 -0.232215  -0.644011 -0.530899
# 1 -0.382310     0.833589  0.965432 -0.232215  -0.644011 -0.666977
# 2 -1.558929    -1.602712 -0.893509 -0.232215  -0.644011 -1.279328
# 3  0.794309     0.007953 -0.893509 -0.232215   2.459870 -0.190704
# 4 -0.382310    -0.371027 -0.893509 -0.232215  -0.644011  0.557724
#
#    yr_renovated   zipcode       lat      long  sqft_lot15  Basement    logbed  \
# 0     -0.512646  1.852530 -0.358097 -0.270092   -0.382516 -0.783865 -0.247469
# 1      1.925604  0.860806  1.142074 -0.752738   -0.160909  1.275730 -0.247469
# 2      1.953771 -0.954235  1.262917 -0.083262   -0.113780 -0.783865 -1.729579
# 3     -0.512646  1.066636 -0.289453 -1.328799   -0.454937  1.275730  0.804104
# 4     -0.512646 -0.093494  0.396994  1.380244   -0.176062 -0.783865 -0.247469
#
#    logsqliv  logfloors
# 0 -1.113191  -0.937308
# 1  0.893865   1.035129
# 2 -2.213885  -0.937308
# 3  0.195200  -0.937308
# 4 -0.202272  -0.937308

# %%
x6_train, x6_test, y6_train, y6_test = train_test_split(x6, y6, test_size=0.2, random_state=42)

# %%
print(len(x6_train), len(x6_test), len(y6_train), len(y6_test))
# Out:
# 15218 3805 15218 3805

# %%
linreg = LinearRegression()
linreg.fit(x6_train, y6_train)

y6_hat_train = linreg.predict(x6_train)
y6_hat_test = linreg.predict(x6_test)

# %%
seventh_train_residuals = y6_hat_train - y6_train
seventh_test_residuals = y6_hat_test - y6_test

# %%
seventh_train_mse = mean_squared_error(y6_train, y6_hat_train)
seventh_test_mse = mean_squared_error(y6_test, y6_hat_test)
print('Train Mean Squared Error:', seventh_train_mse)
print('Test Mean Squared Error:', seventh_test_mse)
print("Train RMSE: ", seventh_train_mse**0.5)
print("Test RMSE: ", seventh_test_mse**0.5)
# Out:
# Train Mean Squared Error: 0.38952433260720504
# Test Mean Squared Error: 0.40793928576977206
# Train RMSE:  0.6241188449383699
# Test RMSE:  0.6387012492314166

# %%
f7 = 'price' + '~' + '+'.join(x6.columns)

# %%
model7 = ols(formula=f7, data=df_scaled).fit()

# %%
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.607
# Method:                 Least Squares   F-statistic:                     1956.
# Date:                Sun, 15 Aug 2021   Prob (F-statistic):               0.00
# Time:                        22:43:42   Log-Likelihood:                -18112.
# No. Observations:               19023   AIC:                         3.626e+04
# Df Residuals:                   19007   BIC:                         3.638e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1.437e-14      0.005  -3.16e-12      1.000      -0.009       0.009
# bedrooms        -0.1923      0.023     -8.476      0.000      -0.237      -0.148
# sqft_living      0.8972      0.022     41.613      0.000       0.855       0.940
# floors           0.0683      0.037      1.828      0.068      -0.005       0.142
# view             0.0975      0.005     20.885      0.000       0.088       0.107
# condition        0.0715      0.005     14.190      0.000       0.062       0.081
# yr_built        -0.1572      0.007    -23.969      0.000      -0.170      -0.144
# yr_renovated     0.0154      0.005      3.355      0.001       0.006       0.024
# zipcode         -0.1207      0.006    -20.420      0.000      -0.132      -0.109
# lat              0.3914      0.005     80.063      0.000       0.382       0.401
# long            -0.0726      0.006    -11.451      0.000      -0.085      -0.060
# sqft_lot15      -0.0172      0.005     -3.436      0.001      -0.027      -0.007
# Basement         0.0150      0.006      2.692      0.007       0.004       0.026
# logbed           0.1210      0.023      5.218      0.000       0.076       0.166
# logsqliv        -0.2646      0.023    -11.584      0.000      -0.309      -0.220
# logfloors        0.0831      0.037      2.220      0.026       0.010       0.156
# ==============================================================================
# Omnibus:                     4605.383   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18476.484
# Skew:                           1.153   Prob(JB):                         0.00
# Kurtosis:                       7.242   Cond. No.                         23.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
resid7 = model7.resid
fig = sm.graphics.qqplot(resid7, dist=stats.norm, line='45', fit=True)

# %%
plt.hist(model7.resid, bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 3.000e+00,
#         2.000e+00, 3.000e+00, 6.000e+00, 6.000e+00, 9.000e+00, 8.000e+00,
#         1.400e+01, 1.700e+01, 2.700e+01, 3.100e+01, 3.900e+01, 5.500e+01,
#         6.700e+01, 7.300e+01, 1.200e+02, 1.560e+02, 2.120e+02, 2.490e+02,
#         3.230e+02, 4.470e+02, 5.140e+02, 6.130e+02, 6.850e+02, 8.150e+02,
#         9.650e+02, 9.770e+02, 1.019e+03, 1.084e+03, 1.113e+03, 1.214e+03,
#         1.122e+03, 1.080e+03, 9.430e+02, 8.050e+02, 6.630e+02, 5.710e+02,
#         4.500e+02, 3.390e+02, 3.200e+02, 2.560e+02, 2.220e+02, 1.790e+02,
#         1.400e+02, 1.250e+02, 1.000e+02, 9.500e+01, 6.200e+01, 7.500e+01,
#         4.400e+01, 6.700e+01, 4.800e+01, 4.100e+01, 4.600e+01, 2.700e+01,
#         3.500e+01, 2.500e+01, 2.600e+01, 2.800e+01, 2.200e+01, 2.400e+01,
#         1.400e+01, 1.400e+01, 1.400e+01, 1.600e+01, 1.100e+01, 1.100e+01,
#         9.000e+00, 4.000e+00, 1.200e+01, 7.000e+00, 5.000e+00, 1.100e+01,
#         8.000e+00, 7.000e+00, 6.000e+00, 6.000e+00, 4.000e+00, 2.000e+00,
#         2.000e+00, 3.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 2.000e+00, 1.000e+00]),
#  array([-3.02102258, -2.94810565, -2.87518872, -2.8022718 , -2.72935487,
#         -2.65643794, -2.58352102, -2.51060409, -2.43768716, -2.36477024,
#         -2.29185331, -2.21893639, -2.14601946, -2.07310253, -2.00018561,
#         -1.92726868, -1.85435175, -1.78143483, -1.7085179 , -1.63560097,
#         -1.56268405, -1.48976712, -1.4168502 , -1.34393327, -1.27101634,
#         -1.19809942, -1.12518249, -1.05226556, -0.97934864, -0.90643171,
#         -0.83351478, -0.76059786, -0.68768093, -0.614764  , -0.54184708,
#         -0.46893015, -0.39601323, -0.3230963 , -0.25017937, -0.17726245,
#         -0.10434552, -0.03142859,  0.04148833,  0.11440526,  0.18732219,
#          0.26023911,  0.33315604,  0.40607297,  0.47898989,  0.55190682,
#          0.62482374,  0.69774067,  0.7706576 ,  0.84357452,  0.91649145,
#          0.98940838,  1.0623253 ,  1.13524223,  1.20815916,  1.28107608,
#          1.35399301,  1.42690994,  1.49982686,  1.57274379,  1.64566071,
#          1.71857764,  1.79149457,  1.86441149,  1.93732842,  2.01024535,
#          2.08316227,  2.1560792 ,  2.22899613,  2.30191305,  2.37482998,
#          2.44774691,  2.52066383,  2.59358076,  2.66649768,  2.73941461,
#          2.81233154,  2.88524846,  2.95816539,  3.03108232,  3.10399924,
#          3.17691617,  3.2498331 ,  3.32275002,  3.39566695,  3.46858388,
#          3.5415008 ,  3.61441773,  3.68733465,  3.76025158,  3.83316851,
#          3.90608543,  3.97900236,  4.05191929,  4.12483621,  4.19775314,
#          4.27067007]),
#  <BarContainer object of 100 artists>)

# %%
plt.scatter(df_scaled['price'], model7.resid)
plt.title('Final Model: Actual Price vs. Residual')
plt.xlabel('Actual Price(Per Million $)')
plt.ylabel('Residual')
plt.show()

# %% [markdown]
# # Final Model: Cross-Validation

# %%
mse = make_scorer(mean_squared_error)

cv_5_results = cross_val_score(linreg, x6, y6, cv=5, scoring=mse)

# %%
cv_5_results
# Out:
# array([0.40403189, 0.39384192, 0.39926059, 0.39005219, 0.3922678 ])

# %% [markdown]
# ## Normality Check (QQ Plot)

# %%
fig = sm.graphics.qqplot(resid1, dist=stats.norm, line='45', fit=True)
fig = sm.graphics.qqplot(resid7, dist=stats.norm, line='45', fit=True)

# %% [markdown]
# ## Normality Check(JB Test)

# %%
name = ['Jarque-Bera','Prob','Skew', 'Kurtosis']
test = sms.jarque_bera(model7.resid)
list(zip(name, test))
# Out:
# [('Jarque-Bera', 18476.483707659623),
#  ('Prob', 0.0),
#  ('Skew', 1.1528911240993607),
#  ('Kurtosis', 7.241917787343773)]
